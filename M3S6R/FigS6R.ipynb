# %%
import pandas as pdb
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from os import listdir
from os.path import isfile, join
import re
import math
import pandas as pd

# %%
def get_files_names():

    filenames = listdir()
    return [filename for filename in filenames if filename.endswith(".csv")]

def open_csv(files):
    
    tab = {}
    for file in files:
        tab[file] = pd.read_csv(file, index_col=0)
    return tab

def transformation(df):
    
    df = df.reset_index()
    df = pd.pivot_table(df, columns="index")
    df = df.reset_index()
    df = df.rename(columns={"index":"Np"})
    df["Np"] = pd.to_numeric(df["Np"])
    df = df.sort_values(by=["Np"])
    df = df.reset_index(drop=True)
    return df

# %%
df = pd.read_csv( "M3S6R10TP1VTO90VTI25VD70PT100PD3.3K1.csv", index_col=0)
df2 = pd.read_csv("M3S6R5TP1VTO90VTI25VD70PT100PD3.3K1.csv", index_col=0)
df3 = pd.read_csv("M3S6R20TP1VTO90VTI25VD70PT100PD3.3K1.csv", index_col=0)
df4 = pd.read_csv("M3S6R30TP1VTO90VTI25VD70PT100PD3.3K1.csv", index_col=0)
df = transformation(df)
df2 = transformation(df2)
df3 = transformation(df3)
df4 = transformation(df4)

# %%
fig = plt.figure(figsize=(15, 15))
plt.plot("Np", "Ct", data=df2,  color="red", linestyle="-", label="R=5 km")
plt.plot("Np", "Ct", data=df3,  color="orange", linestyle="-", label="R=20 km")
plt.plot("Np", "Ct", data=df4,  color="green", linestyle="-", label="R=30 km")
plt.plot("Np", "Ct", data=df,  color="black", linestyle="-", label="R=10 km (Baseline)")
#plt.yticks([100, 200, 300, 400], fontsize=16)
plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40], fontsize=16)
plt.xlabel("Number of delivery points", fontsize=18)
plt.ylabel("Total cost ($/hour)", fontsize=18)
#plt.legend(fontsize=16)
plt.grid()
plt.show()
plt.draw()
fig.savefig("M3S6R")
